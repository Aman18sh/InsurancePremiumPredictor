# %%
# Importing necessary libarary

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report,accuracy_score

# %%
df = pd.read_csv('/content/insurance.csv')

# %%
df.sample(5)
# Out:
#     age  weight  height  income_lpa  smoker     city      occupation  \
# 40   44    57.0    1.53       40.19    True     Pune      unemployed
# 44   59    77.0    1.60       50.00    True  Lucknow     private_job
# 84   75    86.2    1.73        0.62    True   Jaipur         retired
# 85   33    51.4    1.86       34.66   False  Chennai     private_job
# 20   34    58.2    1.85       30.65    True     Gaya  business_owner
#
#    insurance_premium_category
# 40                     Medium
# 44                     Medium
# 84                       High
# 85                        Low
# 20                     Medium

# %%
df['occupation'].unique()
# Out:
# array(['retired', 'freelancer', 'student', 'government_job',
#        'business_owner', 'unemployed', 'private_job'], dtype=object)

# %%
df['smoker'].value_counts()
# Out:
# smoker
# False    57
# True     43
# Name: count, dtype: int64

# %%
df['insurance_premium_category'].value_counts()
# Out:
# insurance_premium_category
# Low       34
# High      33
# Medium    33
# Name: count, dtype: int64

# %%
df_feature = df.copy()

# %%
# Creating new features from existing features

# feature1 : BMI

df_feature['bmi'] = df_feature['weight'] / (df_feature['height']** 2)

# %%
# feature2: Age Group

def age_group(age):
  if age < 25:
    return 'young'
  elif age < 45:
    return 'adult'
  elif age < 60:
    return 'middled_aged'
  else:
    return 'senior'

df_feature['age_group'] = df_feature['age'].apply(age_group)

# %%
# feature3: Lifestyle Risk

def lifestyle_risk(row):
  if row['smoker'] and row['bmi'] > 30:
    return 'high'
  elif row['smoker'] or row['bmi'] > 27:
    return 'medium'
  else:
    return 'low'

# %%
df_feature['lifestyle_risk'] = df_feature.apply(lifestyle_risk,axis=1)

# %%
tier_1_cities = ["Mumbai", "Delhi", "Bangalore", "Chennai", "Kolkata", "Hyderabad", "Pune"]
tier_2_cities = [
    "Jaipur", "Chandigarh", "Indore", "Lucknow", "Patna", "Ranchi", "Visakhapatnam", "Coimbatore",
    "Bhopal", "Nagpur", "Vadodara", "Surat", "Rajkot", "Jodhpur", "Raipur", "Amritsar", "Varanasi",
    "Agra", "Dehradun", "Mysore", "Jabalpur", "Guwahati", "Thiruvananthapuram", "Ludhiana", "Nashik",
    "Allahabad", "Udaipur", "Aurangabad", "Hubli", "Belgaum", "Salem", "Vijayawada", "Tiruchirappalli",
    "Bhavnagar", "Gwalior", "Dhanbad", "Bareilly", "Aligarh", "Gaya", "Kozhikode", "Warangal",
    "Kolhapur", "Bilaspur", "Jalandhar", "Noida", "Guntur", "Asansol", "Siliguri"
]

# %%
#  feature4: City Tier

def city_tier(city):
  if city in tier_1_cities:
    return 'tier_1'
  elif city in tier_2_cities:
    return 'tier_2'
  else:
    return 'tier_3'

# %%
df_feature['city_tier'] = df_feature['city'].apply(city_tier)

# %%
df_feature = df_feature.drop(columns=['age', 'weight', 'height', 'smoker', 'city'])[['income_lpa', 'occupation', 'bmi', 'age_group', 'lifestyle_risk', 'city_tier', 'insurance_premium_category']]
df_feature
# Out:
#     income_lpa      occupation        bmi     age_group lifestyle_risk  \
# 0      2.92000         retired  49.227482        senior         medium
# 1     34.28000      freelancer  30.189017         adult         medium
# 2     36.64000      freelancer  21.118382         adult            low
# 3      3.34000         student  45.535900         young           high
# 4      3.94000         retired  24.296875        senior         medium
# ..         ...             ...        ...           ...            ...
# 95    19.64000  business_owner  21.420747         adult            low
# 96    34.01000     private_job  47.984483         adult         medium
# 97    44.86000      freelancer  18.765432  middled_aged            low
# 98    28.30000  business_owner  30.521676         adult         medium
# 99    28.16664  government_job  27.688778         adult         medium
#
#    city_tier insurance_premium_category
# 0     tier_2                       High
# 1     tier_1                        Low
# 2     tier_2                        Low
# 3     tier_1                     Medium
# 4     tier_2                       High
# ..       ...                        ...
# 95    tier_2                        Low
# 96    tier_1                        Low
# 97    tier_1                        Low
# 98    tier_1                        Low
# 99    tier_1                        Low
#
# [100 rows x 7 columns]

# %%
df_feature[df_feature['bmi']>30]
# Out:
#     income_lpa      occupation        bmi     age_group lifestyle_risk  \
# 0     2.920000         retired  49.227482        senior         medium
# 1    34.280000      freelancer  30.189017         adult         medium
# 3     3.340000         student  45.535900         young           high
# 7    10.865821  government_job  33.360687         adult           high
# 11   10.899387  government_job  31.722551         adult           high
# 12   17.580000      freelancer  30.046711         adult           high
# 14   13.505166  government_job  32.800735  middled_aged         medium
# 17    2.230000         retired  31.176471        senior         medium
# 19    2.790000         student  43.437500         young           high
# 22   30.000000  government_job  31.771627  middled_aged         medium
# 26   23.610000      freelancer  30.477219         adult         medium
# 27   34.330000     private_job  35.159702  middled_aged         medium
# 28   11.630000      unemployed  31.584532         adult         medium
# 29   50.000000  business_owner  42.749310        senior           high
# 32   50.000000     private_job  31.495845  middled_aged         medium
# 34    0.680000         retired  32.914286        senior           high
# 38    1.840000         retired  33.204933        senior           high
# 39   11.990000      unemployed  35.643424  middled_aged           high
# 44   50.000000     private_job  30.078125  middled_aged           high
# 45   18.390000      unemployed  33.466667  middled_aged         medium
# 46   25.570000      unemployed  33.672766         adult           high
# 47    8.340000     private_job  33.286625  middled_aged         medium
# 48   32.690000      unemployed  34.402671         adult           high
# 49    2.290000         student  42.701490         young         medium
# 51   28.950000     private_job  38.827923  middled_aged           high
# 52    2.960000         student  47.344720         young         medium
# 56    2.860000         student  42.414152         young           high
# 59    1.130000         retired  35.835044        senior         medium
# 60   49.940000      unemployed  30.920912         adult           high
# 61   24.050000      unemployed  36.281179         adult           high
# 64    1.020000         retired  37.179649        senior         medium
# 65   38.070000      unemployed  37.662982  middled_aged           high
# 70    0.570000         retired  36.694215        senior         medium
# 72    3.080000         retired  35.499527        senior         medium
# 73    2.220000         retired  32.121628        senior           high
# 76    1.120000         retired  44.044444        senior         medium
# 77    0.610000         retired  37.818734        senior           high
# 80   50.000000      unemployed  34.350461  middled_aged         medium
# 81   22.190000      freelancer  31.866055         adult           high
# 87   25.598370  government_job  32.031250         adult         medium
# 88   30.000000  government_job  31.443698  middled_aged         medium
# 89    4.000000         student  30.458274         young         medium
# 91   28.467885  government_job  38.675103         adult         medium
# 94   10.542289  government_job  33.266002  middled_aged         medium
# 96   34.010000     private_job  47.984483         adult         medium
# 98   28.300000  business_owner  30.521676         adult         medium
#
#    city_tier insurance_premium_category
# 0     tier_2                       High
# 1     tier_1                        Low
# 3     tier_1                     Medium
# 7     tier_1                     Medium
# 11    tier_1                        Low
# 12    tier_2                       High
# 14    tier_3                     Medium
# 17    tier_1                     Medium
# 19    tier_2                       High
# 22    tier_2                        Low
# 26    tier_2                     Medium
# 27    tier_2                     Medium
# 28    tier_1                        Low
# 29    tier_2                       High
# 32    tier_2                     Medium
# 34    tier_3                       High
# 38    tier_2                       High
# 39    tier_1                       High
# 44    tier_2                     Medium
# 45    tier_2                       High
# 46    tier_1                       High
# 47    tier_2                     Medium
# 48    tier_1                     Medium
# 49    tier_3                     Medium
# 51    tier_2                       High
# 52    tier_2                     Medium
# 56    tier_1                     Medium
# 59    tier_2                       High
# 60    tier_2                       High
# 61    tier_2                       High
# 64    tier_2                       High
# 65    tier_2                       High
# 70    tier_2                       High
# 72    tier_2                       High
# 73    tier_1                       High
# 76    tier_2                       High
# 77    tier_1                       High
# 80    tier_2                       High
# 81    tier_2                       High
# 87    tier_1                        Low
# 88    tier_1                        Low
# 89    tier_1                        Low
# 91    tier_1                        Low
# 94    tier_1                        Low
# 96    tier_1                        Low
# 98    tier_1                        Low

# %%
# selecting feature and target value

x = df_feature.drop(columns=['insurance_premium_category'])
y = df_feature['insurance_premium_category']

# %%
x
# Out:
#     income_lpa      occupation        bmi     age_group lifestyle_risk  \
# 0      2.92000         retired  49.227482        senior         medium
# 1     34.28000      freelancer  30.189017         adult         medium
# 2     36.64000      freelancer  21.118382         adult            low
# 3      3.34000         student  45.535900         young           high
# 4      3.94000         retired  24.296875        senior         medium
# ..         ...             ...        ...           ...            ...
# 95    19.64000  business_owner  21.420747         adult            low
# 96    34.01000     private_job  47.984483         adult         medium
# 97    44.86000      freelancer  18.765432  middled_aged            low
# 98    28.30000  business_owner  30.521676         adult         medium
# 99    28.16664  government_job  27.688778         adult         medium
#
#    city_tier
# 0     tier_2
# 1     tier_1
# 2     tier_2
# 3     tier_1
# 4     tier_2
# ..       ...
# 95    tier_2
# 96    tier_1
# 97    tier_1
# 98    tier_1
# 99    tier_1
#
# [100 rows x 6 columns]

# %%
x['lifestyle_risk'].value_counts()
# Out:
# lifestyle_risk
# medium    54
# low       26
# high      20
# Name: count, dtype: int64

# %%
y
# Out:
# 0       High
# 1        Low
# 2        Low
# 3     Medium
# 4       High
#        ...
# 95       Low
# 96       Low
# 97       Low
# 98       Low
# 99       Low
# Name: insurance_premium_category, Length: 100, dtype: object

# %%
# defining categorical and numerical features

categorical_features = ['occupation', 'age_group', 'lifestyle_risk', 'city_tier']
numerical_features = ['income_lpa', 'bmi']

# %%
# creating column transformer for OneHotEncoding

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), categorical_features),
        ('num', 'passthrough', numerical_features)
    ])

# %%
# Create a pipeline with preprocessing and random forest classifier

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(random_state=42))
])

# %%
# splitting the data and training model

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                                   ['occupation', 'age_group',
#                                                    'lifestyle_risk',
#                                                    'city_tier']),
#                                                  ('num', 'passthrough',
#                                                   ['income_lpa', 'bmi'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
y_pred = pipeline.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.85

# %%
x_test.sample(5)
# Out:
#     income_lpa      occupation        bmi     age_group lifestyle_risk  \
# 56    2.860000         student  42.414152         young           high
# 32   50.000000     private_job  31.495845  middled_aged         medium
# 51   28.950000     private_job  38.827923  middled_aged           high
# 69    6.034487  government_job  21.942857  middled_aged            low
# 81   22.190000      freelancer  31.866055         adult           high
#
#    city_tier
# 56    tier_1
# 32    tier_2
# 51    tier_2
# 69    tier_2
# 81    tier_2

# %%
import pickle

# %%
# saving the trained model using pickle

with open('model.pkl', 'wb') as f:
    pickle.dump(pipeline, f)
